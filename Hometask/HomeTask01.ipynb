# %% [markdown]
# ## Упражнение 1.0
#
# Вася и Петя поспорили, что Вася загадает число, проведет ряд математических операций, а Петя угадает полученный результат. Вася загадывает число, прибавляет к нему столько же, умножает на 4 и делит на загаданное число. Петя восторжено восклицает 8 и угадывает, полученный Васей результат. Попробуйте написать программу, повторяющие все шаги и проверте закономерность ли это или Петя просто угадал.

# %% [markdown]
# Программа принимает на вход число x от 1 до 100, после чего
# - прибавляет к нему это же число
# - умножает на 4
# - делит на загаданное число
#
# Ответ выводится на экран

# %%
x = input() # Ввод числа с клавиатуры

# %%
print(result) # Вывод на экран значение переменной result

# %% [markdown]
# ## Упражнение 1.1
# В номерах мобильных телефонов России цифра 8 в начале номера - код России или Казахстана для выхода на межгород. Тем не менее в мире у России другой номер - +7. Другими словами 8 в начале номера будет работать только в России или в Казахстане.

# %% [markdown]
# Требуется написать программу, которая будет принимать от пользователя номер телефона и записывать 8 в номере телефона как +7

# %%
s.replace(s1,s2) # Результатом будет замена подстрочки s1 в строчке s на подстрочку s2

# %% [markdown]
# Обратите внимание, что строчка s останется без изменений. Результат выполнения этой срочки кода следует присвоить переменной

# %% [markdown]
# ## Упражнение 1.2
#
# Вася и Петя снова поспорили. На этот раз число загадывает Петя. Вася плохо понял, как работал фокус Пети, и придумал свой, пусть и не очень красивый. Петя должен будет загадать число, умножить его на 5, отрезать последнюю цифру, после чего вычесть результат целочисленного деления загаданного числа на 2. Получилось 0, довольно заявляет Вася.

# %% [markdown]
# Программа принимает на вход число от 1 до 100, после чего
# - Число умножается на 5
# - От числа удаляется последняя цифра
# - Из результата прошлой операции вычитается результат целочисленного деления первоначального числа на 2
#
# Ответ вывести на экран
